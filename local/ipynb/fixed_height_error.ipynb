# %%
from __future__ import division
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import logomaker

# Set other things
# %matplotlib inline
plt.ion()
# Out:
# Warning: Parameter center_columns not documented.

# %%
logomaker.make_logo(matrix_csvfile='/Users/jkinney/Desktop/ss_linear_regression.txt',
                    csv_index_col='pos',
                    fullheight={0:'G',1:'U'},
                    character_colors='classic',
                    fullheight_colors='black',
                    fullheight_boxcolors='white',
                    fullheight_zorder=20)
# Out:
# <logomaker.Logo.Logo instance at 0x10fff2ab8>

# %%
logomaker.make_logo?
