# %% [markdown]
# # Joint BRCA2 and SMN1 analysis

# %% [markdown]
# import different modules

# %%
# Standard header
# %matplotlib inline
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import pandas as pd
import pdb
import seaborn as sns

# Special imports
from glob import glob
import re
import subprocess
import string
from scipy.stats import pearsonr

# Suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Load data
def load_counts_data(name,libs,reps):
    # Initialize data frame
    counts_df = pd.DataFrame()
    
    if type(libs)==int:
        libs = range(1,libs+1)
    if type(reps)==int:
        reps = range(1,reps+1)
    
    # Merge data frames
    for lib_num in libs:
        for rep_num in reps:
            for rna_type in ['total','exon']:
                counts_file = 'data/%s/%s_lib%d_rep%d_ss_%s.txt'%(name,name,lib_num,rep_num,rna_type)
                col_name = '%s_lib%d_rep%d_%s_ct'%(name,lib_num,rep_num,rna_type)
                print 'Loading data from %s into column %s...'%(counts_file,col_name)
                these_counts_df = pd.read_csv(counts_file,delim_whitespace=True)
                these_counts_df = these_counts_df[['seq','ct']]
                these_counts_df.rename(columns={'ct':col_name},inplace=True)
                if counts_df.empty:
                    counts_df = these_counts_df
                else:
                    counts_df = counts_df.merge(these_counts_df,on='seq',how='outer') 
    
    # Remove invalid splice sites
    rows = [(ss[3:5]=='GT' or ss[3:5]=='GC') for ss in counts_df['seq']]
    counts_df = counts_df.loc[rows,:]
    return counts_df

# %%
# Load data
def load_ratios(name,libs,reps,pseudocount=1.0):
    # Initialize data frame
    ratio_df = pd.DataFrame()
    
    if type(libs)==int:
        libs = range(1,libs+1)
    if type(reps)==int:
        reps = range(1,reps+1)
    
    # Merge data frames
    for lib_num in libs:
        for rep_num in reps:
            # Load counts
            this_ratio_df = load_counts_data(name,libs=[lib_num],reps=[rep_num])
            exon_col_name = '%s_lib%d_rep%d_exon_ct'%(name,lib_num,rep_num)
            total_col_name = '%s_lib%d_rep%d_total_ct'%(name,lib_num,rep_num)
            ratio_col_name = '%s_lib%d_rep%d_ratio'%(name,lib_num,rep_num)
            this_ratio_df[ratio_col_name] = \
                (this_ratio_df[exon_col_name]+pseudocount) / (this_ratio_df[total_col_name]+pseudocount)
            del this_ratio_df[exon_col_name]
            del this_ratio_df[total_col_name]
            if ratio_df.empty:
                ratio_df = this_ratio_df
            else:
                ratio_df = ratio_df.merge(this_ratio_df,on='seq',how='outer') 
    
    # Remove invalid splice sites
    rows = [(ss[3:5]=='GT' or ss[3:5]=='GC') for ss in ratio_df['seq']]
    ratio_df = ratio_df.loc[rows,:]
    
    ratio_df.set_index('seq',drop='True',inplace=True)
    return ratio_df

# %%
brca2_ratio_df = load_ratios('brca2_9nt',libs=2,reps=3)
# Out:
# Loading data from data/brca2_9nt/brca2_9nt_lib1_rep1_ss_total.txt into column brca2_9nt_lib1_rep1_total_ct...
# Loading data from data/brca2_9nt/brca2_9nt_lib1_rep1_ss_exon.txt into column brca2_9nt_lib1_rep1_exon_ct...
# Loading data from data/brca2_9nt/brca2_9nt_lib1_rep2_ss_total.txt into column brca2_9nt_lib1_rep2_total_ct...
# Loading data from data/brca2_9nt/brca2_9nt_lib1_rep2_ss_exon.txt into column brca2_9nt_lib1_rep2_exon_ct...
# Loading data from data/brca2_9nt/brca2_9nt_lib1_rep3_ss_total.txt into column brca2_9nt_lib1_rep3_total_ct...
# Loading data from data/brca2_9nt/brca2_9nt_lib1_rep3_ss_exon.txt into column brca2_9nt_lib1_rep3_exon_ct...
# Loading data from data/brca2_9nt/brca2_9nt_lib2_rep1_ss_total.txt into column brca2_9nt_lib2_rep1_total_ct...
# Loading data from data/brca2_9nt/brca2_9nt_lib2_rep1_ss_exon.txt into column brca2_9nt_lib2_rep1_exon_ct...
# Loading data from data/brca2_9nt/brca2_9nt_lib2_rep2_ss_total.txt into column brca2_9nt_lib2_rep2_total_ct...
# Loading data from data/brca2_9nt/brca2_9nt_lib2_rep2_ss_exon.txt into column brca2_9nt_lib2_rep2_exon_ct...
# Loading data from data/brca2_9nt/brca2_9nt_lib2_rep3_ss_total.txt into column brca2_9nt_lib2_rep3_total_ct...
# Loading data from data/brca2_9nt/brca2_9nt_lib2_rep3_ss_exon.txt into column brca2_9nt_lib2_rep3_exon_ct...

# %%
brca2_ratio_df.head()
# Out:
#            brca2_9nt_lib1_rep1_ratio  brca2_9nt_lib1_rep2_ratio  \
# seq
# ACGGTCCAT                   0.041640                   0.068738
# ATTGCCAGG                   0.076823                   0.151316
# ACAGCGGTA                   0.273288                   0.332178
# AAGGTGGGA                   7.887314                  11.309231
# ACGGCTTGG                   0.043232                   0.073359
#
#            brca2_9nt_lib1_rep3_ratio  brca2_9nt_lib2_rep1_ratio  \
# seq
# ACGGTCCAT                   0.157676                   0.054983
# ATTGCCAGG                   0.200447                   0.198986
# ACAGCGGTA                   0.455556                   0.618343
# AAGGTGGGA                  10.754286                  17.692913
# ACGGCTTGG                   0.145624                   0.069486
#
#            brca2_9nt_lib2_rep2_ratio  brca2_9nt_lib2_rep3_ratio
# seq
# ACGGTCCAT                   0.062921                   0.382771
# ATTGCCAGG                   0.166443                   0.411273
# ACAGCGGTA                   0.528107                   0.628468
# AAGGTGGGA                  17.695748                  10.224478
# ACGGCTTGG                   0.064565                   0.333717

# %%
smn1_ratio_df = load_ratios('smn1_9nt',libs=3,reps=3)
smn1_ratio_df.head()
# Out:
# Loading data from data/smn1_9nt/smn1_9nt_lib1_rep1_ss_total.txt into column smn1_9nt_lib1_rep1_total_ct...
# Loading data from data/smn1_9nt/smn1_9nt_lib1_rep1_ss_exon.txt into column smn1_9nt_lib1_rep1_exon_ct...
# Loading data from data/smn1_9nt/smn1_9nt_lib1_rep2_ss_total.txt into column smn1_9nt_lib1_rep2_total_ct...
# Loading data from data/smn1_9nt/smn1_9nt_lib1_rep2_ss_exon.txt into column smn1_9nt_lib1_rep2_exon_ct...
# Loading data from data/smn1_9nt/smn1_9nt_lib1_rep3_ss_total.txt into column smn1_9nt_lib1_rep3_total_ct...
# Loading data from data/smn1_9nt/smn1_9nt_lib1_rep3_ss_exon.txt into column smn1_9nt_lib1_rep3_exon_ct...
# Loading data from data/smn1_9nt/smn1_9nt_lib2_rep1_ss_total.txt into column smn1_9nt_lib2_rep1_total_ct...
# Loading data from data/smn1_9nt/smn1_9nt_lib2_rep1_ss_exon.txt into column smn1_9nt_lib2_rep1_exon_ct...
# Loading data from data/smn1_9nt/smn1_9nt_lib2_rep2_ss_total.txt into column smn1_9nt_lib2_rep2_total_ct...
# Loading data from data/smn1_9nt/smn1_9nt_lib2_rep2_ss_exon.txt into column smn1_9nt_lib2_rep2_exon_ct...
# Loading data from data/smn1_9nt/smn1_9nt_lib2_rep3_ss_total.txt into column smn1_9nt_lib2_rep3_total_ct...
# Loading data from data/smn1_9nt/smn1_9nt_lib2_rep3_ss_exon.txt into column smn1_9nt_lib2_rep3_exon_ct...
# Loading data from data/smn1_9nt/smn1_9nt_lib3_rep1_ss_total.txt into column smn1_9nt_lib3_rep1_total_ct...
# Loading data from data/smn1_9nt/smn1_9nt_lib3_rep1_ss_exon.txt into column smn1_9nt_lib3_rep1_exon_ct...
# Loading data from data/smn1_9nt/smn1_9nt_lib3_rep2_ss_total.txt into column smn1_9nt_lib3_rep2_total_ct...
# Loading data from data/smn1_9nt/smn1_9nt_lib3_rep2_ss_exon.txt into column smn1_9nt_lib3_rep2_exon_ct...
# Loading data from data/smn1_9nt/smn1_9nt_lib3_rep3_ss_total.txt into column smn1_9nt_lib3_rep3_total_ct...
# Loading data from data/smn1_9nt/smn1_9nt_lib3_rep3_ss_exon.txt into column smn1_9nt_lib3_rep3_exon_ct...
#            smn1_9nt_lib1_rep1_ratio  smn1_9nt_lib1_rep2_ratio  \
# seq
# CGAGCTTGC                  0.013441                  0.088769
# ATTGCATAA                       NaN                  0.009138
# CTGGTAAGT                  0.684211                  5.625210
# CAAGTAATC                  0.020370                  0.204513
# TATGCTGAT                       NaN                  0.018767
#
#            smn1_9nt_lib1_rep3_ratio  smn1_9nt_lib2_rep1_ratio  \
# seq
# CGAGCTTGC                  0.038621                  0.054217
# ATTGCATAA                  0.006502                  0.029900
# CTGGTAAGT                  2.489260                  7.128440
# CAAGTAATC                  0.122075                  0.490196
# TATGCTGAT                  0.012658                  0.007843
#
#            smn1_9nt_lib2_rep2_ratio  smn1_9nt_lib2_rep3_ratio  \
# seq
# CGAGCTTGC                  0.014045                  0.020921
# ATTGCATAA                  0.006702                  0.009259
# CTGGTAAGT                  2.721186                  2.318898
# CAAGTAATC                  0.148438                  0.200000
# TATGCTGAT                  0.010955                  0.009646
#
#            smn1_9nt_lib3_rep1_ratio  smn1_9nt_lib3_rep2_ratio  \
# seq
# CGAGCTTGC                  0.044643                  1.047619
# ATTGCATAA                  0.005089                  0.169811
# CTGGTAAGT                  3.254854                 73.928571
# CAAGTAATC                  0.227273                  2.875000
# TATGCTGAT                  0.012165                  0.090909
#
#            smn1_9nt_lib3_rep3_ratio
# seq
# CGAGCTTGC                  0.026549
# ATTGCATAA                  0.015038
# CTGGTAAGT                100.928571
# CAAGTAATC                  2.000000
# TATGCTGAT                  0.011278

# %%
ratios_df = smn1_ratio_df.merge(brca2_ratio_df,left_index=True,right_index=True,how='outer')
ratios_df.head()
# Out:
#            smn1_9nt_lib1_rep1_ratio  smn1_9nt_lib1_rep2_ratio  \
# seq
# AAAGCAAAA                       NaN                       NaN
# AAAGCAAAC                       NaN                  0.036145
# AAAGCAAAG                       NaN                  0.072289
# AAAGCAAAT                       NaN                  0.016393
# AAAGCAACA                       NaN                  0.024096
#
#            smn1_9nt_lib1_rep3_ratio  smn1_9nt_lib2_rep1_ratio  \
# seq
# AAAGCAAAA                       NaN                  0.018868
# AAAGCAAAC                  0.021583                  0.044944
# AAAGCAAAG                       NaN                  0.029412
# AAAGCAAAT                  0.017192                  0.012945
# AAAGCAACA                       NaN                  0.105263
#
#            smn1_9nt_lib2_rep2_ratio  smn1_9nt_lib2_rep3_ratio  \
# seq
# AAAGCAAAA                  0.013514                  0.013953
# AAAGCAAAC                  0.021858                       NaN
# AAAGCAAAG                  0.027211                  0.034483
# AAAGCAAAT                  0.009124                  0.011429
# AAAGCAACA                  0.019802                       NaN
#
#            smn1_9nt_lib3_rep1_ratio  smn1_9nt_lib3_rep2_ratio  \
# seq
# AAAGCAAAA                  0.012658                  0.076923
# AAAGCAAAC                  0.029197                  0.212121
# AAAGCAAAG                  0.008696                  0.069767
# AAAGCAAAT                  0.006652                  0.159091
# AAAGCAACA                  0.021277                  0.421053
#
#            smn1_9nt_lib3_rep3_ratio  brca2_9nt_lib1_rep1_ratio  \
# seq
# AAAGCAAAA                       NaN                   0.028037
# AAAGCAAAC                  0.032520                   0.072165
# AAAGCAAAG                  0.014925                   0.111111
# AAAGCAAAT                  0.028302                   0.048232
# AAAGCAACA                  0.035294                   0.052083
#
#            brca2_9nt_lib1_rep2_ratio  brca2_9nt_lib1_rep3_ratio  \
# seq
# AAAGCAAAA                   0.049020                   0.071429
# AAAGCAAAC                   0.055046                   0.177778
# AAAGCAAAG                   0.074468                   0.183486
# AAAGCAAAT                   0.061017                   0.160714
# AAAGCAACA                   0.081633                   0.113475
#
#            brca2_9nt_lib2_rep1_ratio  brca2_9nt_lib2_rep2_ratio  \
# seq
# AAAGCAAAA                   0.108571                   0.058065
# AAAGCAAAC                   0.183673                        NaN
# AAAGCAAAG                   0.028169                        NaN
# AAAGCAAAT                   0.051852                        NaN
# AAAGCAACA                   0.078947                   0.032000
#
#            brca2_9nt_lib2_rep3_ratio
# seq
# AAAGCAAAA                   0.432292
# AAAGCAAAC                   0.448276
# AAAGCAAAG                   0.348624
# AAAGCAAAT                   0.289216
# AAAGCAACA                   0.253968

# %%
def sample_correlations(ratios_df, samples, min_ratio=.5, clone_file='data/clones.txt'):
    """Compute correlations between specified samples"""
    n = len(samples)
    k=1
    rhos = np.zeros([n,n])
                
    # Load calibration data
    clones_df = pd.read_csv(clone_file, delim_whitespace=True)
    
    # Get a list of 11nt splice sites with 100% inclusion
    ss_11nt_top = clones_df['ss'][clones_df['incl_pct']==100]

    # Now isolate clones that correspond to just 9 nt variants
    ss_9nt_100pct = [ss[:-2] for ss in ss_11nt_top if ss[-2:]=='TT']

    print ss_9nt_100pct
        
    for i in range(n):
        for j in range(n):
            sample_x = samples[i]
            sample_y = samples[j]
                        
            # Get median of full inclusion clones
            ratio_libX_100pct = np.mean(ratios_df[sample_x][ss_9nt_100pct])
            ratio_libY_100pct = np.mean(ratios_df[sample_y][ss_9nt_100pct])
                
            #assert ~np.isnan(ratio_libX_100pct)
                
            x = ratios_df[sample_x]/ratio_libX_100pct
            y = ratios_df[sample_y]/ratio_libY_100pct
                        
            indices = np.isreal(x.values) & np.isreal(y.values) & (x.values >= min_ratio) & (y.values >= min_ratio)
                        
            #nas = np.logical_or(np.isnan(x.values), np.isnan(y.values))
            rho, p = pearsonr(x.values[indices],y.values[indices])
            rhos[i,j] = rho
    return rhos
            
def plot_sample_correlations(title,ratios_df,min_ratio=0,clim=[0,1]):
    """ 
    Plot correlations between 
    specified samples
    """
    plt.figure(figsize=[8,8])
    sns.reset_orig()
    samples = ratios_df.columns
    rhos = sample_correlations(ratios_df,samples,min_ratio=min_ratio)
    plt.imshow(rhos**2,interpolation='nearest',clim=clim)
    plt.colorbar()
    n = len(samples)
    plt.xticks(range(n), samples, rotation='vertical',fontsize=20)
    plt.yticks(range(n), samples,fontsize=20)
    plt.title('%s: $R^2$ coefficients'%title)
    plt.set_cmap('PiYG')
    plt.tight_layout()

# %%
smn1_9nt_samples = [name for name in ratios_df.columns.values if 'smn1_9nt' in name] 
smn1_9nt_df = ratios_df[smn1_9nt_samples]
smn1_9nt_df.columns = [' '.join(x.split('_')[2:4]) for x in smn1_9nt_df.columns]
smn1_9nt_df.head()
# Out:
#            lib1 rep1  lib1 rep2  lib1 rep3  lib2 rep1  lib2 rep2  lib2 rep3  \
# seq
# AAAGCAAAA        NaN        NaN        NaN   0.018868   0.013514   0.013953
# AAAGCAAAC        NaN   0.036145   0.021583   0.044944   0.021858        NaN
# AAAGCAAAG        NaN   0.072289        NaN   0.029412   0.027211   0.034483
# AAAGCAAAT        NaN   0.016393   0.017192   0.012945   0.009124   0.011429
# AAAGCAACA        NaN   0.024096        NaN   0.105263   0.019802        NaN
#
#            lib3 rep1  lib3 rep2  lib3 rep3
# seq
# AAAGCAAAA   0.012658   0.076923        NaN
# AAAGCAAAC   0.029197   0.212121   0.032520
# AAAGCAAAG   0.008696   0.069767   0.014925
# AAAGCAAAT   0.006652   0.159091   0.028302
# AAAGCAACA   0.021277   0.421053   0.035294

# %%
plot_sample_correlations('SMN1 9nt',smn1_9nt_df,min_ratio=0.0,clim=[0,1])
plt.savefig('results/smn1_9nt_crosscorr.png')
# Out:
# ['CAGGCAAGT', 'CAGGTAAGT', 'CAGGTAAAT', 'GAGGCAAGT', 'CAGGCGAGT']

# %%
brca2_9nt_samples = [name for name in ratios_df.columns.values if 'brca2_9nt' in name] 
brca2_9nt_df = ratios_df[brca2_9nt_samples]
brca2_9nt_df.columns = [' '.join(x.split('_')[2:4]) for x in brca2_9nt_df.columns]
plot_sample_correlations('BRCA2 9nt',brca2_9nt_df,min_ratio=0.0,clim=[0,1])
plt.savefig('results/brca2_9nt_crosscorr.png')
# Out:
# ['CAGGCAAGT', 'CAGGTAAGT', 'CAGGTAAAT', 'GAGGCAAGT', 'CAGGCGAGT']

# %%
all_samples = [name for name in ratios_df.columns.values if '9nt' in name] 
all_df = ratios_df[all_samples]
all_df.columns = [' '.join(x.split('_')[0:4]) for x in all_df.columns]
plot_sample_correlations('All samples',all_df,min_ratio=0.0,clim=[0,1])
plt.savefig('results/all_crosscorr.png')
# Out:
# ['CAGGCAAGT', 'CAGGTAAGT', 'CAGGTAAAT', 'GAGGCAAGT', 'CAGGCGAGT']

# %%
# Load calibration data
clone_file='data/clones.txt'
clones_df = pd.read_csv(clone_file, delim_whitespace=True)

# Get a list of 11nt splice sites with 100% inclusion
ss_11nt_top = clones_df['ss'][clones_df['incl_pct']==100]

# Now isolate clones that correspond to just 9 nt variants
ss_9nt_100pct = [ss[:-2] for ss in ss_11nt_top if ss[-2:]=='TT']

#brca2_100pct = np.median(ratios_df['brca2_9nt_lib1_rep1_ratio'][ss_9nt_100pct])
#smn1_100pct = np.median(ratios_df['smn2_9nt_lib1_rep1_ratio'][ss_9nt_100pct])

# Renormalize each replicate independently
all_samples = [name for name in ratios_df.columns.values if '9nt' in name] 
all_df = ratios_df[all_samples]
for col in all_df.columns:
    all_df.loc[:,col] *= 100/np.median(all_df[col][ss_9nt_100pct])
    
all_df.head(20)
# Out:
#            smn1_9nt_lib1_rep1_ratio  smn1_9nt_lib1_rep2_ratio  \
# seq
# AAAGCAAAA                       NaN                       NaN
# AAAGCAAAC                       NaN                  0.587818
# AAAGCAAAG                       NaN                  1.175637
# AAAGCAAAT                       NaN                  0.266606
# AAAGCAACA                       NaN                  0.391879
# AAAGCAACC                       NaN                  0.396658
# AAAGCAACG                 28.235294                 19.244521
# AAAGCAACT                  4.660194                  0.631572
# AAAGCAAGA                  8.648649                  8.432654
# AAAGCAAGC                       NaN                  1.204665
# AAAGCAAGG                       NaN                       NaN
# AAAGCAAGT                       NaN                  1.742462
# AAAGCAATA                       NaN                  0.306849
# AAAGCAATC                  3.764706                       NaN
# AAAGCAATG                       NaN                  0.537619
# AAAGCAATT                       NaN                  0.290410
# AAAGCACAA                       NaN                  1.336683
# AAAGCACAC                 10.322581                  1.478452
# AAAGCACAG                       NaN                  0.469124
# AAAGCACAT                  3.478261                  0.699483
#
#            smn1_9nt_lib1_rep3_ratio  smn1_9nt_lib2_rep1_ratio  \
# seq
# AAAGCAAAA                       NaN                  0.246448
# AAAGCAAAC                  0.635920                  0.587045
# AAAGCAAAG                       NaN                  0.384169
# AAAGCAAAT                  0.506549                  0.169084
# AAAGCAACA                       NaN                  1.374921
# AAAGCAACC                       NaN                  0.602850
# AAAGCAACG                  9.709821                  4.353917
# AAAGCAACT                  0.605431                  0.544240
# AAAGCAAGA                  3.466387                  4.353917
# AAAGCAAGC                  1.403061                       NaN
# AAAGCAAGG                       NaN                  1.632719
# AAAGCAAGT                  2.118347                  0.907066
# AAAGCAATA                  0.346639                  0.232209
# AAAGCAATC                  0.521492                  0.810031
# AAAGCAATG                       NaN                  0.233246
# AAAGCAATT                       NaN                  0.306135
# AAAGCACAA                       NaN                  7.718308
# AAAGCACAC                       NaN                  2.252026
# AAAGCACAG                  0.866597                  0.816360
# AAAGCACAT                  0.512422                  0.681483
#
#            smn1_9nt_lib2_rep2_ratio  smn1_9nt_lib2_rep3_ratio  \
# seq
# AAAGCAAAA                  0.450378                  0.515286
# AAAGCAAAC                  0.728480                       NaN
# AAAGCAAAG                  0.906883                  1.273408
# AAAGCAAAT                  0.304087                  0.422044
# AAAGCAACA                  0.659960                       NaN
# AAAGCAACC                  0.275438                  0.439629
# AAAGCAACG                  5.332474                  7.640449
# AAAGCAACT                  0.634818                  1.468761
# AAAGCAAGA                  3.999356                  1.943623
# AAAGCAAGC                  2.515318                  3.014599
# AAAGCAAGG                  1.063658                       NaN
# AAAGCAAGT                  1.904455                  2.238111
# AAAGCAATA                  0.228796                  0.885280
# AAAGCAATC                  0.592497                       NaN
# AAAGCAATG                  0.203716                  0.416100
# AAAGCAATT                  0.235700                  0.315631
# AAAGCACAA                  2.563690                       NaN
# AAAGCACAC                  0.966028                  2.954307
# AAAGCACAG                  1.211926                  2.238111
# AAAGCACAT                  0.323572                  0.769351
#
#            smn1_9nt_lib3_rep1_ratio  smn1_9nt_lib3_rep2_ratio  \
# seq
# AAAGCAAAA                  0.478504                  0.100301
# AAAGCAAAC                  1.103703                  0.276587
# AAAGCAAAG                  0.328712                  0.090971
# AAAGCAAAT                  0.251453                  0.207441
# AAAGCAACA                  0.804294                  0.549015
# AAAGCAACC                       NaN                  0.325978
# AAAGCAACG                  3.566211                  2.437748
# AAAGCAACT                  1.050051                  0.448220
# AAAGCAAGA                  5.400262                  2.607823
# AAAGCAAGC                       NaN                  0.977934
# AAAGCAAGG                  5.968710                  0.931366
# AAAGCAAGT                  3.041527                  0.782347
# AAAGCAATA                  0.420020                  0.444515
# AAAGCAATC                  3.150153                  0.237075
# AAAGCAATG                  0.365824                  0.125376
# AAAGCAATT                  0.615665                  0.325978
# AAAGCACAA                  1.350065                  0.372546
# AAAGCACAC                       NaN                       NaN
# AAAGCACAG                  2.520122                       NaN
# AAAGCACAT                  0.572755                  0.314737
#
#            smn1_9nt_lib3_rep3_ratio  brca2_9nt_lib1_rep1_ratio  \
# seq
# AAAGCAAAA                       NaN                   0.283688
# AAAGCAAAC                       NaN                   0.730181
# AAAGCAAAG                       NaN                   1.124247
# AAAGCAAAT                       NaN                   0.488017
# AAAGCAACA                       NaN                   0.526991
# AAAGCAACC                       NaN                   0.481820
# AAAGCAACG                       NaN                  26.138734
# AAAGCAACT                       NaN                   0.580554
# AAAGCAAGA                       NaN                   0.538943
# AAAGCAAGC                       NaN                   0.446392
# AAAGCAAGG                       NaN                   1.227829
# AAAGCAAGT                       NaN                   1.073637
# AAAGCAATA                       NaN                   0.356867
# AAAGCAATC                       NaN                        NaN
# AAAGCAATG                       NaN                   1.264777
# AAAGCAATT                       NaN                   0.374749
# AAAGCACAA                       NaN                   0.489591
# AAAGCACAC                       NaN                   0.694388
# AAAGCACAG                       NaN                   0.316194
# AAAGCACAT                       NaN                   0.626792
#
#            brca2_9nt_lib1_rep2_ratio  brca2_9nt_lib1_rep3_ratio  \
# seq
# AAAGCAAAA                   0.326550                   0.555701
# AAAGCAAAC                   0.366695                   1.383078
# AAAGCAAAG                   0.496078                   1.427489
# AAAGCAAAT                   0.406472                   1.250328
# AAAGCAACA                   0.543806                   0.882816
# AAAGCAACC                   0.710573                   0.622385
# AAAGCAACG                  34.048280                  48.474241
# AAAGCAACT                   0.773224                   1.257344
# AAAGCAAGA                   0.411529                   1.006480
# AAAGCAAGC                   0.214891                   0.630796
# AAAGCAAGG                   1.168065                   2.006256
# AAAGCAAGT                   0.701223                   0.966121
# AAAGCAATA                   0.377721                   1.138510
# AAAGCAATC                   0.380664                   1.178760
# AAAGCAATG                   0.475830                   1.111402
# AAAGCAATT                   0.378501                   0.606219
# AAAGCACAA                   0.425794                   0.887738
# AAAGCACAC                   0.498731                   1.187446
# AAAGCACAG                   0.376059                   1.719749
# AAAGCACAT                   0.476622                   1.317663
#
#            brca2_9nt_lib2_rep1_ratio  brca2_9nt_lib2_rep2_ratio  \
# seq
# AAAGCAAAA                   0.466451                   0.293227
# AAAGCAAAC                   0.789108                        NaN
# AAAGCAAAG                   0.121021                        NaN
# AAAGCAAAT                   0.222769                        NaN
# AAAGCAACA                   0.339178                   0.161601
# AAAGCAACC                   0.186794                   0.805076
# AAAGCAACG                   0.660962                        NaN
# AAAGCAACT                   0.252721                   0.412247
# AAAGCAAGA                   0.379081                   0.291836
# AAAGCAAGC                   0.537032                        NaN
# AAAGCAAGG                   1.675074                   1.052901
# AAAGCAAGT                   1.256883                   0.360716
# AAAGCAATA                   0.503590                   0.360716
# AAAGCAATC                   1.503689                   1.147733
# AAAGCAATG                        NaN                        NaN
# AAAGCAATT                   0.452237                   0.108603
# AAAGCACAA                   0.246506                   0.497153
# AAAGCACAC                   0.325782                   0.216430
# AAAGCACAG                   0.193525                   0.416974
# AAAGCACAT                   0.367500                   0.302584
#
#            brca2_9nt_lib2_rep3_ratio
# seq
# AAAGCAAAA                   3.362684
# AAAGCAAAC                   3.487021
# AAAGCAAAG                   2.711854
# AAAGCAAAT                   2.249733
# AAAGCAACA                   1.975553
# AAAGCAACC                   3.680263
# AAAGCAACG                   8.643042
# AAAGCAACT                   2.845880
# AAAGCAAGA                   2.860967
# AAAGCAAGC                   5.762028
# AAAGCAAGG                   3.139491
# AAAGCAAGT                   3.013108
# AAAGCAATA                   2.917027
# AAAGCAATC                   1.795093
# AAAGCAATG                   2.917027
# AAAGCAATT                   1.909327
# AAAGCACAA                   2.898447
# AAAGCACAC                   2.849355
# AAAGCACAG                   2.718376
# AAAGCACAT                   2.761011

# %%
# Get BRCA2 median ratios
brca2_cols = [c for c in all_df.columns if 'brca2_9nt' in c]
all_df['brca2_median'] = all_df[brca2_cols].median(axis=1,skipna=False)

# Get SMN1 median ratios
smn1_cols = [c for c in all_df.columns if ('smn1_9nt_lib2' in c)]
print smn1_cols
all_df['smn1_median'] = all_df[smn1_cols].median(axis=1,skipna=False)

# Get SMN1 median ratios
smn1_cols_alt = [c for c in all_df.columns if (('smn1_9nt' in c) and (not 'lib1_rep1' in c) and (not 'lib3_rep3' in c) and (not 'lib2' in c))]
print smn1_cols_alt
all_df['smn1_median_alt'] = all_df[smn1_cols_alt].median(axis=1,skipna=False)

# Get SMN1 median ratios
smn1_cols_7 = [c for c in all_df.columns if (('smn1_9nt' in c) and (not 'lib1_rep1' in c) and (not 'lib3_rep3' in c))]
print smn1_cols_7
all_df['smn1_median_7'] = all_df[smn1_cols_7].median(axis=1,skipna=False)

# Extract smn1 and brca2 median values. Drop rows with any NaNs
df = all_df[['brca2_median','smn1_median','smn1_median_alt','smn1_median_7']].dropna(axis=0,how='any')
# Out:
# ['smn1_9nt_lib2_rep1_ratio', 'smn1_9nt_lib2_rep2_ratio', 'smn1_9nt_lib2_rep3_ratio']
# ['smn1_9nt_lib1_rep2_ratio', 'smn1_9nt_lib1_rep3_ratio', 'smn1_9nt_lib3_rep1_ratio', 'smn1_9nt_lib3_rep2_ratio']
# ['smn1_9nt_lib1_rep2_ratio', 'smn1_9nt_lib1_rep3_ratio', 'smn1_9nt_lib2_rep1_ratio', 'smn1_9nt_lib2_rep2_ratio', 'smn1_9nt_lib2_rep3_ratio', 'smn1_9nt_lib3_rep1_ratio', 'smn1_9nt_lib3_rep2_ratio']

# %%
xcol = 'smn1_median'
ycol = 'smn1_median_alt'

plt.figure(figsize=[6,6])
plt.plot(df[xcol],df[ycol],'.k')

plt.xlim([0,200])
plt.ylim([0,200])
plt.xlabel('smn1_median_lib2')
plt.ylabel('smn1_median_other')
#plt.legend(loc='upper left')
plt.tight_layout()
plt.title('SMN1 lib2 median vs. other median')
plt.savefig('results/smn1_lib2_other_scatter.png')

# %%
# Keep only rows with sufficient activity in one of the two samples
min_splicing = 30
indices = (df['brca2_median'] > min_splicing) | (df['smn1_median'] > min_splicing )

# Plot splicing levels
sns.jointplot(x='brca2_median',y='smn1_median',data=df[indices],xlim=[0,150],ylim=[0,150],kind='scatter')

# %%
# Identify variants in 3 different regions of the above plot.
# Save plot and 10 seqs from each of the 3 regions
np.random.seed(123)
def get_indices_in_region(in_df,xcol,ycol,x0,y0,dx,dy,num_seqs='all'):
    indices = (abs(in_df[xcol] - x0) < dx) & (abs(in_df[ycol] - y0) < dy)
    out_df = in_df[indices]
    
    if num_seqs == 'all':
        num_seqs = len(out_df)
        print 'Setting num_seqs to %d'%num_seqs
    
    assert len(out_df) > 0, 'No sequences to output'
    
    # Randomize rows and select num_seqs sequences
    if num_seqs > len(out_df):
        num_seqs = len(out_df)
        print "Not enough seqs meeting criteria. Setting num_seqs to %d"%num_seqs
        
    print num_seqs
    indices = range(num_seqs)
    np.random.shuffle(indices)
    out_df = out_df.iloc[indices,:]
    return out_df

xcol = 'brca2_median'
ycol = 'smn1_median'
df1 = get_indices_in_region(df,xcol=xcol,ycol=ycol,x0=100,y0=100,dx=10,dy=10)
df2 = get_indices_in_region(df,xcol=xcol,ycol=ycol,x0=50,y0=50,dx=10,dy=10)
df3 = get_indices_in_region(df,xcol=xcol,ycol=ycol,x0=0,y0=100,dx=5,dy=20)
df4 = get_indices_in_region(df,xcol=xcol,ycol=ycol,x0=0,y0=50,dx=2,dy=5)
df5 = get_indices_in_region(df,xcol=xcol,ycol=ycol,x0=50,y0=0,dx=20,dy=5)
df6 = get_indices_in_region(df,xcol=xcol,ycol=ycol,x0=0,y0=25,dx=5,dy=5)


markersize=15
plt.figure(figsize=[6,6])
plt.plot(df[xcol],df[ycol],'.',color='k',label='all')
if any(df1):
    df1 = get_indices_in_region(df,xcol=xcol,ycol=ycol,x0=100,y0=100,dx=10,dy=10)
    plt.plot(df1[xcol],df1[ycol],'.',label='brca2_hi_smn1_hi',markersize=markersize)
    print '\nBRCA2 hi, SMN1 hi'
    print df1.head()
    df1.to_csv('results/brca2_hi_smn1_hi.csv')
    
if any(df2):
    plt.plot(df2[xcol],df2[ycol],'.',label='brca2_mid_smn1_mid',markersize=markersize)
    print '\nBRCA2 mid, SMN1 mid'
    print df2.head()
    df2.to_csv('results/brca2_mid_smn1_mid.csv')
    
if any(df3):
    plt.plot(df3[xcol],df3[ycol],'.',label='brca2_low_smn1_hi',markersize=markersize)
    print '\nBRCA2 low, SMN1 hi'
    print df3.head()
    df3.to_csv('results/brca2_low_smn1_hi.csv')   

if any(df4):
    print '\nBRCA2 low, SMN1 mid'
    print df4.head()
    df4.to_csv('results/brca2_low_smn1_mid.csv')
    plt.plot(df4[xcol],df4[ycol],'.',label='brca2_low_smn1_mid',markersize=markersize)

if any(df5):
    print '\nBRCA2 mid, SMN1 low'
    print df5.head()
    df5.to_csv('results/brca2_mid_smn1_low.csv')
    plt.plot(df5[xcol],df5[ycol],'.',label='brca2_mid_smn1_low',markersize=markersize)

if any(df6):
    print '\nMandys request 17.05.18'
    print df6.head(10)
    df5.to_csv('results/mandys_request_17.05.18.csv')
    plt.plot(df6[xcol],df6[ycol],'.',label='Mandys request',markersize=markersize)

# Mark orriginal BRCA2 and SMN1 splice site sequences (From 17.05.18 email from Mandy)
brca2_seq = 'CAGGCAAGT'  
smn1_seq = 'GGAGTAAGT' 

x = df.loc[brca2_seq,'brca2_median']
y = df.loc[brca2_seq,'smn1_median']
label='BRCA2 site'
plt.plot(x,y,'.',label=label,markersize=markersize)
print '%s (%s): brca2_median = %d, smn1_median = %d'%(label,brca2_seq,x,y)
  
x = df.loc[smn1_seq,'brca2_median']
y = df.loc[smn1_seq,'smn1_median']
label='SMN1 site'
plt.plot(x,y,'.',label=label,markersize=markersize)
print '%s (%s): brca2_median = %d, smn1_median = %d'%(label,smn1_seq,x,y)
    
plt.xlim([0,160])
plt.ylim([0,160])
plt.xlabel(xcol)
plt.ylabel(ycol)
plt.legend(loc='lower right')
plt.tight_layout()
plt.savefig('results/brca2_smn1_scatter.pdf')
# Out:
# Setting num_seqs to 107
# 107
# Setting num_seqs to 16
# 16
# Setting num_seqs to 8
# 8
# Setting num_seqs to 14
# 14
# Setting num_seqs to 11
# 11
# Setting num_seqs to 346
# 346
# Setting num_seqs to 107
# 107
#
# BRCA2 hi, SMN1 hi
#            brca2_median  smn1_median  smn1_median_alt  smn1_median_7
# seq
# GAGGTTTGT     96.723477    91.731910        92.292816      92.202894
# CAGGTATAT    102.823816   105.419354       111.590999     109.354027
# TGGGTAAGA     98.694713   106.319319       117.500399     108.948556
# GAGGTAAAA     98.000062   105.918937       100.052364     105.437559
# TGGGTACGT     97.521271   101.689374       102.174907     101.689374
#
# BRCA2 mid, SMN1 mid
#            brca2_median  smn1_median  smn1_median_alt  smn1_median_7
# seq
# ACGGTATCT     49.411623    51.430650        66.438689      51.562500
# CTGGTAGGG     49.983171    52.315855        72.433104      69.673965
# TTGGTAAAT     50.782253    42.884829        68.911655      49.051943
# TAGGTATAT     46.916035    49.325387        42.585694      49.325387
# CAGGTGCAT     59.779086    52.247009        41.071686      44.196429
#
# BRCA2 low, SMN1 hi
#            brca2_median  smn1_median  smn1_median_alt  smn1_median_7
# seq
# GAAGCGGTA      0.950323    86.910891        62.663414      71.727575
# GAGGTGCTA      0.666340    91.432266        26.530820      39.576957
# GGTGCCGAT      0.987734    83.879104        61.063100      73.019057
# GGTGCCTGT      3.351787    83.925512       104.269544      87.875822
# GGTGCCGTA      0.932036    96.209344       129.274975      97.484294
#
# BRCA2 low, SMN1 mid
#            brca2_median  smn1_median  smn1_median_alt  smn1_median_7
# seq
# GGTGTCGGA      0.616149    46.132998        67.903363      56.702748
# CGTGCAAGA      0.486786    49.238452        10.749133      17.640855
# GATGCGGAG      0.514693    52.247009        41.215166      46.651786
# GGTGCCATT      1.442347    45.095794        37.162966      43.964548
# GGTGCTTTT      0.773705    49.697284        54.596445      49.697284
#
# BRCA2 mid, SMN1 low
#            brca2_median  smn1_median  smn1_median_alt  smn1_median_7
# seq
# ACAGTTAAG     54.507003     4.353917         0.648556       2.104592
# CAGGTTATG     33.858280     1.466115         1.222696       1.466115
# CTGGTACTG     40.580305     2.878013         4.556507       2.878013
# TAGGTATAG     33.445289     4.081798         7.053089       5.040244
# ATGGCAAGT     47.516345     0.518948         1.826719       1.588911
#
# Mandys request 17.05.18
#            brca2_median  smn1_median  smn1_median_alt  smn1_median_7
# seq
# AGCGTGGAT      0.404151    25.773252        23.102908      24.312965
# GAAGTGCCC      0.871518    20.516022         8.976458      19.592629
# CCAGTGGAT      0.579192    21.513474        24.926266      23.418685
# GGAGCGACT      0.777875    24.783838        23.016670      23.073845
# AGGGTCCGT      2.178291    23.500170        25.366411      23.500170
# AACGTCGGA      0.513337    21.107710        16.633011      16.836735
# GGAGTCCCG      1.070591    24.995973        34.443285      24.995973
# GCCGCGATT      0.727705    20.829977        10.784001      13.830091
# GTCGTCCAT      0.591366    20.028020        12.341376      15.120733
# TACGTCGAT      3.817920    21.488689        13.404193      19.102613
# BRCA2 site (CAGGCAAGT): brca2_median = 102, smn1_median = 110
# SMN1 site (GGAGTAAGT): brca2_median = 87, smn1_median = 108

# %%
# Extract GC splice sites; index by flanks
indices_gc = np.array([seq[3:5]=='GC' for seq in all_df.index])
gc_df = all_df.loc[indices_gc,['brca2_median']]
flanks = [s[:3]+'..'+s[5:] for s in gc_df.index] 
gc_df['flanks'] = flanks
gc_df.reset_index(inplace=True,drop=False)
gc_df.set_index('flanks',drop=True,inplace=True)
gc_df.rename(columns={'seq':'GC_seq','brca2_median':'brca2_median_GC'},inplace=True)

# Extract GT splice sites; index by flanks
indices_gt = np.array([seq[3:5]=='GT' for seq in all_df.index])
gt_df = all_df.loc[indices_gt,['brca2_median']]
flanks = [s[:3]+'..'+s[5:] for s in gt_df.index] 
gt_df['flanks'] = flanks
gt_df.reset_index(inplace=True,drop=False)
gt_df.set_index('flanks',drop=True,inplace=True)
gt_df.rename(columns={'seq':'GT_seq','brca2_median':'brca2_median_GT'},inplace=True)

# Merge GC and GT dataframes and drop NAN results
gcgt_df = gt_df.merge(gc_df,left_index=True,right_index=True)
gcgt_df.dropna(inplace=True)

# Remove likely shifted sites
indices = [s[1:3] != 'GT' for s in gcgt_df.index]
gcgt_df = gcgt_df.loc[indices,:]
print gcgt_df.head()
# Out:
#               GT_seq  brca2_median_GT     GC_seq  brca2_median_GC
# flanks
# AAA..AACA  AAAGTAACA         1.193634  AAAGCAACA         0.535398
# AAA..AAGA  AAAGTAAGA        67.589574  AAAGCAAGA         0.475236
# AAA..AAGG  AAAGTAAGG        62.665403  AAAGCAAGG         1.451451
# AAA..AAGT  AAAGTAAGT        75.669587  AAAGCAAGT         1.019879
# AAA..AATA  AAAGTAATA         0.842171  AAAGCAATA         0.440656

# %%
xcol = 'brca2_median_GT'
ycol = 'brca2_median_GC'
df1 = get_indices_in_region(gcgt_df,xcol=xcol,ycol=ycol,x0=100,y0=100,dx=20,dy=20,num_seqs=5)
df1_label='brca2_GT_hi_GC_hi'
df2 = get_indices_in_region(gcgt_df,xcol=xcol,ycol=ycol,x0=100,y0=50,dx=20,dy=10,num_seqs=5)
df2_label='brca2_GT_hi_GC_mid'
df3 = get_indices_in_region(gcgt_df,xcol=xcol,ycol=ycol,x0=100,y0=0,dx=5,dy=5,num_seqs=5)
df3_label='brca2_GT_hi_GC_low'
df4 = get_indices_in_region(gcgt_df,xcol=xcol,ycol=ycol,x0=50,y0=0,dx=5,dy=5,num_seqs=5)
df4_label='brca2_GT_mid_GC_low'
#df5 = get_indices_in_region(gcgt_df,xcol=xcol,ycol=ycol,x0=0,y0=50,dx=20,dy=30,num_seqs='all')
#df5_label='brca2_GT_low_GC_mid'


markersize=15
plt.figure(figsize=[6,6])
plt.plot(gcgt_df[xcol],gcgt_df[ycol],'.k',label='all')
plt.plot(df1[xcol],df1[ycol],'.',label=df1_label,markersize=markersize)
plt.plot(df2[xcol],df2[ycol],'.',label=df2_label,markersize=markersize)
plt.plot(df3[xcol],df3[ycol],'.',label=df3_label,markersize=markersize)
plt.plot(df4[xcol],df4[ycol],'.',label=df4_label,markersize=markersize)
plt.plot(df5[xcol],df5[ycol],'.',label=df5_label,markersize=markersize)

plt.xlim([0,160])
plt.ylim([0,160])
plt.xlabel(xcol)
plt.ylabel(ycol)
plt.legend(loc='upper right')
plt.tight_layout()
plt.savefig('results/gc_gt_scatter.pdf')

print '\n'+df1_label
print df1
df1.to_csv('results/'+df1_label+'.csv')

print '\n'+df2_label
print df2
df2.to_csv('results/'+df2_label+'.csv')

print '\n'+df3_label
print df3
df3.to_csv('results/'+df3_label+'.csv')

print '\n'+df4_label
print df4
df4.to_csv('results/'+df4_label+'.csv')

print '\n'+df5_label
print df5
df5.to_csv('results/'+df5_label+'.csv')
# Out:
# 5
# 5
# 5
# 5
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-4c26db427859> in <module>()
#      20 plt.plot(df3[xcol],df3[ycol],'.',label=df3_label,markersize=markersize)
#      21 plt.plot(df4[xcol],df4[ycol],'.',label=df4_label,markersize=markersize)
# ---> 22 plt.plot(df5[xcol],df5[ycol],'.',label=df5_label,markersize=markersize)
#      23
#      24 plt.xlim([0,160])
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'brca2_median_GT'

# %%
# Extract GC splice sites; index by flanks
indices_gc = np.array([seq[3:5]=='GC' for seq in all_df.index])
gc_df = all_df.loc[indices_gc,['smn1_median']]
flanks = [s[:3]+'..'+s[5:] for s in gc_df.index] 
gc_df['flanks'] = flanks
gc_df.reset_index(inplace=True,drop=False)
gc_df.set_index('flanks',drop=True,inplace=True)
gc_df.rename(columns={'seq':'GC_seq','smn1_median':'smn1_median_GC'},inplace=True)

# Extract GT splice sites; index by flanks
indices_gt = np.array([seq[3:5]=='GT' for seq in all_df.index])
gt_df = all_df.loc[indices_gt,['smn1_median']]
flanks = [s[:3]+'..'+s[5:] for s in gt_df.index] 
gt_df['flanks'] = flanks
gt_df.reset_index(inplace=True,drop=False)
gt_df.set_index('flanks',drop=True,inplace=True)
gt_df.rename(columns={'seq':'GT_seq','smn1_median':'smn1_median_GT'},inplace=True)

# Merge GC and GT dataframes and drop NAN results
gcgt_df = gt_df.merge(gc_df,left_index=True,right_index=True)
gcgt_df.dropna(inplace=True)

# Remove likely shifted sites
indices = [s[1:3] != 'GT' for s in gcgt_df.index]
gcgt_df = gcgt_df.loc[indices,:]
print gcgt_df.head()
# Out:
#               GT_seq  smn1_median_GT     GC_seq  smn1_median_GC
# flanks
# AAA..AAAA  AAAGTAAAA        0.453442  AAAGCAAAA        0.450378
# AAA..AAAG  AAAGTAAAG        0.984105  AAAGCAAAG        0.906883
# AAA..AAAT  AAAGTAAAT        0.834939  AAAGCAAAT        0.304087
# AAA..AACC  AAAGTAACC        1.119579  AAAGCAACC        0.439629
# AAA..AACT  AAAGTAACT        0.475479  AAAGCAACT        0.634818

# %%
xcol = 'smn1_median_GT'
ycol = 'smn1_median_GC'
df1 = get_indices_in_region(gcgt_df,xcol=xcol,ycol=ycol,x0=100,y0=100,dx=10,dy=10,num_seqs=5)
df1_label='smn1_GT_hi_GC_hi'
df2 = get_indices_in_region(gcgt_df,xcol=xcol,ycol=ycol,x0=100,y0=0,dx=5,dy=5,num_seqs=5)
df2_label='smn1_GT_hi_GC_low'
#df3 = get_indices_in_region(gcgt_df,xcol=xcol,ycol=ycol,x0=0,y0=100,dx=5,dy=15,num_seqs=5)
#df3_label='smn1_GT_low_GC_hi'
#df4 = get_indices_in_region(gcgt_df,xcol=xcol,ycol=ycol,x0=50,y0=100,dx=15,dy=15,num_seqs=5)
#df4_label='smn1_GT_mid_GC_hi'


markersize=15
plt.figure(figsize=[6,6])
plt.plot(gcgt_df[xcol],gcgt_df[ycol],'.k',label='all')
plt.plot(df1[xcol],df1[ycol],'.',label=df1_label,markersize=markersize)
plt.plot(df2[xcol],df2[ycol],'.',label=df2_label,markersize=markersize)
#plt.plot(df3[xcol],df3[ycol],'.',label=df3_label,markersize=markersize)
#plt.plot(df4[xcol],df4[ycol],'.',label=df4_label,markersize=markersize)

plt.xlim([0,160])
plt.ylim([0,160])
plt.xlabel(xcol)
plt.ylabel(ycol)
plt.legend(loc='upper right')
plt.tight_layout()
plt.savefig('smn1_gc_gt_scatter.pdf')

print '\n'+df1_label
print df1
df1.to_csv('results/'+df1_label+'.csv')

print '\n'+df2_label
print df2
df2.to_csv('results/'+df2_label+'.csv')

#print '\n'+df3_label
#print df3
#df3.to_csv(df3_label+'.csv')

#print '\n'+df4_label
#print df4
#df4.to_csv(df4_label+'.csv')
# Out:
# Not enough seqs meeting criteria. Setting num_seqs to 2
# 2
# 5
#
# smn1_GT_hi_GC_hi
#               GT_seq  smn1_median_GT     GC_seq  smn1_median_GC
# flanks
# AAG..AAGG  AAGGTAAGG       96.592779  AAGGCAAGG       96.938202
# AAG..AAGT  AAGGTAAGT      102.678259  AAGGCAAGT       98.881707
#
# smn1_GT_hi_GC_low
#               GT_seq  smn1_median_GT     GC_seq  smn1_median_GC
# flanks
# AAC..ATGT  AACGTATGT       97.790368  AACGCATGT        0.400938
# AAG..ATTT  AAGGTATTT       98.229474  AAGGCATTT        0.466778
# AAC..AAGG  AACGTAAGG       98.097312  AACGCAAGG        3.029815
# AAG..AACA  AAGGTAACA      103.443941  AAGGCAACA        0.562497
# AAG..AATA  AAGGTAATA       97.420202  AAGGCAATA        0.291074

# %%
ss_motif = 'NNNGYNNNN'

# %%
# Compute MaxEnt scores on all splice sites
import os, sys

def make_iupac_seqs(iupac_motif):
    """Returns a list of all DNA sequences that match an IUPAC motif"""
    iupac_dict = {
        'A':'A',
        'C':'C',
        'G':'G',
        'T':'T',
        'R':'AG',
        'Y':'CT',
        'S':'GC',
        'W':'AT',
        'K':'GT',
        'M':'AC',
        'B':'CGT',
        'D':'AGT',
        'H':'ACT',
        'V':'ACG',
        'N':'ACGT'
        }
    
    if len(iupac_motif) == 0:
        return ['']
    else:
        # Recursively get subseqs
        suffix_seqs = make_iupac_seqs(iupac_motif[1:])
        
        # Get prefix characters
        key = iupac_motif[0]
        assert key in iupac_dict.keys(), 'Invalid character: %s'%key
        prefix_chars = iupac_dict[key]
        
        # Build new sequences
        seqs = [c+s for c in prefix_chars for s in suffix_seqs]
        return seqs
    
seqs = make_iupac_seqs('NNNGYNNNN')
print len(seqs)
# Out:
# 32768

# %%
import os

# Write all candidate splice sites to file
splice_sites_gt = make_iupac_seqs('NNNGTNNNN') 
f = open('splice_sites.txt','w')
f.write('\n'.join(splice_sites_gt)+'\n')
f.close()

# Run maxentscan
os.chdir('maxentscan')
os.system('perl score5.pl ../splice_sites.txt > ../maxent_scores.txt')
os.chdir('..')

# Load results into dataframe
maxent_df = pd.read_csv('maxent_scores.txt',header=None,names=['seq','maxent'],delim_whitespace=True)
maxent_df.set_index('seq',inplace=True)
maxent_df.head()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-28-d419b491b875> in <module>()
#       8
#       9 # Run maxentscan
# ---> 10 os.chdir('maxentscan')
#      11 os.system('perl score5.pl ../splice_sites.txt > ../maxent_scores.txt')
#      12 os.chdir('..')
#
# OSError: [Errno 2] No such file or directory: 'maxentscan'

# %%
# 17.04.17 read in multiple types of scores from MaxEntScan's website
scores_df = pd.read_csv('scored_splice_sites.txt',header=None,delim_whitespace=True)
scores_df.rename(columns={0:'seq',2:'MaxEnt',4:'MDD',6:'MM',8:'WMM'},inplace=True)
scores_df.drop([1,3,5,7], axis=1,inplace=True) 
scores_df.set_index('seq',drop=True,inplace=True)
scores_df.head()

# Extract smn1 and brca2 median values. Drop rows with any NaNs
medians_df = all_df[['brca2_median','smn1_median']].dropna(axis=0,how='any')

# Add in median measurments to scores_df
df = scores_df.merge(medians_df,left_index=True,right_index=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-29-1d6e574fdd88> in <module>()
#       1 # 17.04.17 read in multiple types of scores from MaxEntScan's website
# ----> 2 scores_df = pd.read_csv('scored_splice_sites.txt',header=None,delim_whitespace=True)
#       3 scores_df.rename(columns={0:'seq',2:'MaxEnt',4:'MDD',6:'MM',8:'WMM'},inplace=True)
#       4 scores_df.drop([1,3,5,7], axis=1,inplace=True)
#       5 scores_df.set_index('seq',drop=True,inplace=True)
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     644                     skip_blank_lines=skip_blank_lines)
#     645
# --> 646         return _read(filepath_or_buffer, kwds)
#     647
#     648     parser_f.__name__ = name
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     387
#     388     # Create the parser.
# --> 389     parser = TextFileReader(filepath_or_buffer, **kwds)
#     390
#     391     if (nrows is not None) and (chunksize is not None):
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     728             self.options['has_index_names'] = kwds['has_index_names']
#     729
# --> 730         self._make_engine(self.engine)
#     731
#     732     def close(self):
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     921     def _make_engine(self, engine='c'):
#     922         if engine == 'c':
# --> 923             self._engine = CParserWrapper(self.f, **self.options)
#     924         else:
#     925             if engine == 'python':
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1388         kwds['allow_leading_cols'] = self.index_col is not False
#    1389
# -> 1390         self._reader = _parser.TextReader(src, **kwds)
#    1391
#    1392         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:4184)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:8449)()
#
# IOError: File scored_splice_sites.txt does not exist

# %%
import os
# Use the Kraskov estimator to compute the amount of mutual information in each relationship
def kraskov_MI(xs,ys,k_neighbors,noise=1E-8):
    N = len(xs)
    assert len(ys) == N
    tmp_df = pd.DataFrame()
    tmp_df['x'] = xs
    tmp_df['y'] = ys
    in_file_name = 'kraskov_input_df.txt'
    out_file_name = 'mi.txt'
    tmp_df.to_csv(in_file_name,sep='\t',header=False,index=False)

    command = """
    ./MIhigherdim %s 2 1 1 %d %d %f > %s
    """%(in_file_name,N,k_neighbors,noise,out_file_name)
    os.system(command)
    
    f = open(out_file_name,'r')
    mi = float(f.readline().strip())
    return mi

# %%
markersize=15
plt.figure(figsize=[10,5])
alpha = 0.05
xl = [0,160]
k_neighbors = 10
noise = 0.01
#yl = [-40,20]

score_cols = ['MaxEnt','MDD','MM','WMM']
K = len(score_cols)
for i, ycol in enumerate(score_cols):
    xcol = 'brca2_median'

    #df1 = get_indices_in_region(scored_df,xcol='smn1_median',ycol=ycol,x0=110,y0=-20,dx=30,dy=10,num_seqs=20)
    #df1_label='smn1_hi_maxent_low'

    # Plot brca2_median vs. maxent
    plt.subplot(2,K,i+1)
    plt.plot(df[xcol],df[ycol],'.b',label='all',alpha=alpha)
    #plt.plot(df1[xcol],df1[ycol],'.',label=df1_label,markersize=markersize)
    plt.xlim(xl)
    #plt.ylim(yl)
    plt.xlabel(xcol)
    plt.ylabel(ycol)
    #plt.legend(loc='lower right')
    mi = kraskov_MI(df[xcol],df[ycol],k_neighbors=k_neighbors,noise=noise)
    plt.title('MI: %0.3f bits'%mi)

    # Plot smn1_median vs. maxent
    plt.subplot(2,K,i+1+K)
    xcol = 'smn1_median'
    plt.plot(df[xcol],df[ycol],'.b',label='all',alpha=alpha)
    #plt.plot(df1[xcol],df1[ycol],'.',label=df1_label,markersize=markersize)
    plt.xlim(xl)
    #plt.ylim(yl)
    plt.xlabel(xcol)
    plt.ylabel(ycol)
    #plt.legend(loc='lower right')
    mi = kraskov_MI(df[xcol],df[ycol],k_neighbors=k_neighbors,noise=noise)
    plt.title('MI: %0.3f bits'%mi)
    
plt.tight_layout()
plt.savefig('scores_v_measurements.png')

#print '\n'+df1_label
#print df1
#df1.to_csv(df1_label+'.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-deddf5eb7392> in <module>()
#      17     # Plot brca2_median vs. maxent
#      18     plt.subplot(2,K,i+1)
# ---> 19     plt.plot(df[xcol],df[ycol],'.b',label='all',alpha=alpha)
#      20     #plt.plot(df1[xcol],df1[ycol],'.',label=df1_label,markersize=markersize)
#      21     plt.xlim(xl)
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'MaxEnt'

# %%
# !head kraskov_input_df.csv
# Out:
# head: kraskov_input_df.csv: No such file or directory

# %%
# Extract smn1 and brca2 median values. Drop rows with any NaNs
df = all_df[['brca2_median','smn1_median']].dropna(axis=0,how='any')
validation_df = pd.read_excel('library_validation_list.xlsx',header=1)
validation_medians_df = df.loc[validation_df.index,:]
validation_medians_df.to_excel('validation_medians.xlsx')
validation_medians_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-33-d5c498ccb5c2> in <module>()
#       1 # Extract smn1 and brca2 median values. Drop rows with any NaNs
#       2 df = all_df[['brca2_median','smn1_median']].dropna(axis=0,how='any')
# ----> 3 validation_df = pd.read_excel('library_validation_list.xlsx',header=1)
#       4 validation_medians_df = df.loc[validation_df.index,:]
#       5 validation_medians_df.to_excel('validation_medians.xlsx')
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/io/excel.pyc in read_excel(io, sheetname, header, skiprows, skip_footer, index_col, names, parse_cols, parse_dates, date_parser, na_values, thousands, convert_float, has_index_names, converters, true_values, false_values, engine, squeeze, **kwds)
#     189
#     190     if not isinstance(io, ExcelFile):
# --> 191         io = ExcelFile(io, engine=engine)
#     192
#     193     return io._parse_excel(
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/io/excel.pyc in __init__(self, io, **kwds)
#     247             self.book = xlrd.open_workbook(file_contents=data)
#     248         elif isinstance(io, compat.string_types):
# --> 249             self.book = xlrd.open_workbook(io)
#     250         else:
#     251             raise ValueError('Must explicitly set engine if not passing in'
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/xlrd/__init__.pyc in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     392         peek = file_contents[:peeksz]
#     393     else:
# --> 394         f = open(filename, "rb")
#     395         peek = f.read(peeksz)
#     396         f.close()
#
# IOError: [Errno 2] No such file or directory: 'library_validation_list.xlsx'

# %%
# Analyze list of human splice sites
human_df = pd.read_excel('human_splice_sites.xlsx',header=0)
human_df.head()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-34-b7a4c2ba161d> in <module>()
#       1 # Analyze list of human splice sites
# ----> 2 human_df = pd.read_excel('human_splice_sites.xlsx',header=0)
#       3 human_df.head()
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/io/excel.pyc in read_excel(io, sheetname, header, skiprows, skip_footer, index_col, names, parse_cols, parse_dates, date_parser, na_values, thousands, convert_float, has_index_names, converters, true_values, false_values, engine, squeeze, **kwds)
#     189
#     190     if not isinstance(io, ExcelFile):
# --> 191         io = ExcelFile(io, engine=engine)
#     192
#     193     return io._parse_excel(
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/io/excel.pyc in __init__(self, io, **kwds)
#     247             self.book = xlrd.open_workbook(file_contents=data)
#     248         elif isinstance(io, compat.string_types):
# --> 249             self.book = xlrd.open_workbook(io)
#     250         else:
#     251             raise ValueError('Must explicitly set engine if not passing in'
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/xlrd/__init__.pyc in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     392         peek = file_contents[:peeksz]
#     393     else:
# --> 394         f = open(filename, "rb")
#     395         peek = f.read(peeksz)
#     396         f.close()
#
# IOError: [Errno 2] No such file or directory: 'human_splice_sites.xlsx'

# %%
# Extract GT splice sites
human_GT_df = human_df.iloc[:,:2]
human_GT_df.columns = ['human_ct','seq']
human_GT_df.dropna(how='any',axis=0,inplace=True)
human_GT_df.set_index('seq',drop=True,inplace=True)
human_GT_df['GT'] = True

# Extract GC splice sites
human_GC_df = human_df.iloc[:,6:8]
human_GC_df.columns = ['human_ct','seq']
human_GC_df.dropna(how='any',axis=0,inplace=True)
human_GC_df.set_index('seq',drop=True,inplace=True)
human_GC_df['GT'] = False

# Concatenate GT and GC splice site data frames
human_GY_df = pd.concat([human_GT_df, human_GC_df],axis=0,join='outer')
human_GY_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-521058b28081> in <module>()
#       1 # Extract GT splice sites
# ----> 2 human_GT_df = human_df.iloc[:,:2]
#       3 human_GT_df.columns = ['human_ct','seq']
#       4 human_GT_df.dropna(how='any',axis=0,inplace=True)
#       5 human_GT_df.set_index('seq',drop=True,inplace=True)
#
# NameError: name 'human_df' is not defined

# %%
# Merge into median values
df = medians_df.merge(human_GY_df,left_index=True,right_index=True,how='outer')
df.fillna(0,inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-f1045573bb50> in <module>()
#       1 # Merge into median values
# ----> 2 df = medians_df.merge(human_GY_df,left_index=True,right_index=True,how='outer')
#       3 df.fillna(0,inplace=True)
#       4 df.head()
#
# NameError: name 'medians_df' is not defined

# %%
# Plot counts vs median values
plt.figure(figsize=[12,6])

indices = [s[1:3] != 'GT' for s in df.index]

xcol = 'brca2_median'
ycol = 'human_ct'
xs = df.loc[indices,xcol]
ys = df.loc[indices,ycol]+1
K = len(ys)
epsilons = np.random.rand(K)

plt.subplot(1,2,1)
plt.loglog(xs,ys+epsilons,'.',alpha=.1)
plt.xlabel(xcol)
plt.ylabel(ycol+'+1+jitter')
plt.axhline(2)

xcol = 'smn1_median'
ycol = 'human_ct'
xs = df.loc[indices,xcol]
ys = df.loc[indices,ycol]+1
K = len(ys)
epsilons = np.random.rand(K)

plt.subplot(1,2,2)
plt.loglog(xs,ys+epsilons,'.',alpha=.1)
plt.xlabel(xcol)
plt.ylabel(ycol+'+1+jitter')
plt.axhline(2)

plt.tight_layout()
plt.savefig('human_ct_vs_medians.png')

# Note: maybe we should remove all sites that have 'GT' as seq[1:2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-4c2b46355f50> in <module>()
#       7 ycol = 'human_ct'
#       8 xs = df.loc[indices,xcol]
# ----> 9 ys = df.loc[indices,ycol]+1
#      10 K = len(ys)
#      11 epsilons = np.random.rand(K)
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1308
#    1309         if type(key) is tuple:
# -> 1310             return self._getitem_tuple(key)
#    1311         else:
#    1312             return self._getitem_axis(key, axis=0)
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#     794     def _getitem_tuple(self, tup):
#     795         try:
# --> 796             return self._getitem_lowerdim(tup)
#     797         except IndexingError:
#     798             pass
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_lowerdim(self, tup)
#     920         for i, key in enumerate(tup):
#     921             if is_label_like(key) or isinstance(key, tuple):
# --> 922                 section = self._getitem_axis(key, axis=i)
#     923
#     924                 # we have yielded a scalar ?
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1480
#    1481         # fall thru to straight lookup
# -> 1482         self._has_valid_type(key, axis)
#    1483         return self._get_label(key, axis=axis)
#    1484
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _has_valid_type(self, key, axis)
#    1417                 raise
#    1418             except:
# -> 1419                 error()
#    1420
#    1421         return True
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in error()
#    1404                                     "key")
#    1405                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1406                                (key, self.obj._get_axis_name(axis)))
#    1407
#    1408             try:
#
# KeyError: 'the label [human_ct] is not in the [columns]'

# %%
# 17.05.18
# Plot highly sliced sequences in both BRCA2 and SMN1 contexts that are not in the human genome. 
indices = (df['brca2_median'] > 50) & (df['smn1_median'] > 50) & (df['human_ct'] == 0)
tmp_df = df[indices]
tmp_df.head()

xcol = 'brca2_median'
ycol = 'smn1_median'
xs = tmp_df[xcol]
ys = tmp_df[ycol]

plt.plot(xs,ys,'.')
plt.xlabel(xcol)
plt.ylabel(ycol)
plt.xlim([0,200])
plt.ylim([0,200])

plt.title('Found %d sequences'%len(xs))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-f7af3d200736> in <module>()
#       1 # 17.05.18
#       2 # Plot highly sliced sequences in both BRCA2 and SMN1 contexts that are not in the human genome.
# ----> 3 indices = (df['brca2_median'] > 50) & (df['smn1_median'] > 50) & (df['human_ct'] == 0)
#       4 tmp_df = df[indices]
#       5 tmp_df.head()
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/jkinney/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'human_ct'

# %%
indices = [s[1:3] != 'GT' for s in tmp_df.index]
tmp_df[indices]
